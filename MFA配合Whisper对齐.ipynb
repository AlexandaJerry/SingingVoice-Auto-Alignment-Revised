# %%
# %%capture
# !pip install git+https://github.com/openai/whisper.git

# %%
# !git clone https://github.com/AlexandaJerry/SingingVoice-Auto-Alignment-Revised
# !rm -rf /content/SingingVoice-Auto-Alignment-Revised/my_wavs
# !rm -rf /content/SingingVoice-Auto-Alignment-Revised/my_lyrics
# !rm -rf /content/SingingVoice-Auto-Alignment-Revised/audio/*
# !rm -rf /content/SingingVoice-Auto-Alignment-Revised/srt_files/*
# !rm -rf /content/SingingVoice-Auto-Alignment-Revised/my_textgrid/*
# !rm -rf /content/SingingVoice-Auto-Alignment-Revised/my_textgrid_converted
# !rm -rf /content/SingingVoice-Auto-Alignment-Revised/my_textgrid_final
# Out:
# Cloning into 'SingingVoice-Auto-Alignment-Revised'...
# remote: Enumerating objects: 477, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 477 (delta 6), reused 12 (delta 4), pack-reused 458
# Receiving objects: 100% (477/477), 138.63 MiB | 15.44 MiB/s, done.
# Resolving deltas: 100% (231/231), done.

# %%
# !cp -r /content/SingingVoice-Auto-Alignment-Revised/transcribe.py /usr/local/lib/python3.7/dist-packages/whisper
# !cp -r /content/SingingVoice-Auto-Alignment-Revised/utils.py /usr/local/lib/python3.7/dist-packages/whisper

# %%
import whisper
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]

# %%
# %cd /content/SingingVoice-Auto-Alignment-Revised/audio
from google.colab import files
uploaded = files.upload()
#这里传下降噪后的歌声或者是纯净的普通说话干声
# Out:
# /content/SingingVoice-Auto-Alignment-Revised/audio
#      <input type="file" id="files-334c7c1a-cb05-42e9-b6f7-e635fa142e7d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-334c7c1a-cb05-42e9-b6f7-e635fa142e7d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# %cd /content/SingingVoice-Auto-Alignment-Revised
# !whisper "./audio"
# Out:
# /content/SingingVoice-Auto-Alignment-Revised
# 100%|████████████████████████████████████████| 461M/461M [00:01<00:00, 272MiB/s]
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: chinese
# [00:00.000 --> 00:08.000] 荒草叢生的情绪 倒也过的安稳
# [00:08.000 --> 00:14.000] 代替你陪着我的十年轮
# [00:14.000 --> 00:19.000] 人群过了城之温 影在我的嘴唇
# [00:19.000 --> 00:26.000] 回忆骨色的温恨 是竖竿
# [00:26.000 --> 00:30.000] 全是情绪的情绪 倒也过的安稳
# [00:30.000 --> 00:35.000] 代替你陪着我的十年轮
# [00:35.000 --> 00:39.000] 代替你陪着我的十年轮
# [00:39.000 --> 00:46.000] 是竖竿 全是手来的冒伤
# [00:46.000 --> 00:53.000] 却遮住了魂魂 寒夜生活一个人
# [00:53.000 --> 01:00.000] 等清晨 时间最毒的仇恨
# [01:00.000 --> 01:07.000] 是永远却无分 可惜你从未心疼
# [01:07.000 --> 01:14.000] 我的笨 荒草叢生的情绪
# [01:14.000 --> 01:23.000] 倒也过的安稳 代替你陪着我的十年轮
# [01:23.000 --> 01:27.000] 数着一圈 十年轮
# [01:27.000 --> 01:32.000] 我认真将心事都封存
# [01:32.000 --> 01:37.000] 秘密妈妈说我的自尊
# [01:37.000 --> 01:45.000] 受该一次次离奔 我承认 曾幻想我永恒
# [01:45.000 --> 02:02.000] 可惜从没人陪我演 却是笨
# ...

# %%
# !pip install pydub
# !pip install unidecode
# !pip install pypinyin
# !python auto.py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Folder ./srt_files/ exists.. continuing processing..
# Folder ./audio/ exists.. continuing processing..
# Encoding srt_file(s) to utf8...
# Encoding of 2-file(s) changed
# ---------------------------------------------------------------------
# Extracting information from srt_file(s) to csv_files
# 2-file(s) converted and saved as csv-files to ./csv
# ---------------------------------------------------------------------
# Downsampling wav files...
# File  1  completed: 年轮
# File  2  completed: 起风了
# Downsampling complete
# ---------------------------------------------------------------------
# The script took  0.8612444400787354  seconds to run
# ...

# %%
# !pip install -q condacolab
import condacolab
condacolab.install_miniconda()
# !conda create -n aligner -c conda-forge montreal-forced-aligner
# Out:
# ⏬ Downloading https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:20
# 🔁 Restarting kernel...
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 4.14.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/aligner
#
#   added / updated specs:
#     - montreal-forced-aligner
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     ansiwrap-0.8.4             |             py_0           9 KB  conda-forge
# ...

# %%
#上面的崩溃是因为安装完MFA要重启运行时
#对齐好的Textgrid在my_textgrid文件夹下
# !source activate aligner; \
mfa align /content/SingingVoice-Auto-Alignment-Revised/my_corpus /content/SingingVoice-Auto-Alignment-Revised/MFA_pretrained_model/opencpop_dictionary.txt /content/SingingVoice-Auto-Alignment-Revised/MFA_pretrained_model/Acoustic_Model_300iteration.zip /content/SingingVoice-Auto-Alignment-Revised/my_textgrid --beam 100
# Out:
# WARNING - The previous run had a different configuration than the current, which may cause issues. Please see the log
#                    for details or use --clean flag if issues are encountered.
# INFO - Setting up corpus information...
# INFO - Found 1 speaker across 90 files, average number of utterances per speaker: 90.0
# INFO - Initializing multiprocessing jobs...
# WARNING - Number of jobs was specified as 3, but due to only having 1 speakers, MFA will only use 1 jobs.
# INFO - Creating corpus split with features...
# INFO - Alignment already done, skipping.
# INFO - Exporting TextGrids to /content/SingingVoice-Auto-Alignment-Revised/my_textgrid...
# 100% 90/90 [00:00<00:00, 326.00it/s]
# INFO - Finished exporting TextGrids to /content/SingingVoice-Auto-Alignment-Revised/my_textgrid!
# INFO - Done! Everything took 1.1219966411590576 seconds

# %%
#打包下载命令
# !tar -zcvf aligned.tar /content/SingingVoice-Auto-Alignment-Revised/my_textgrid
# Out:
# tar: Removing leading `/' from member names
# /content/SingingVoice-Auto-Alignment-Revised/my_textgrid/
# /content/SingingVoice-Auto-Alignment-Revised/my_textgrid/起风了_57.TextGrid
# /content/SingingVoice-Auto-Alignment-Revised/my_textgrid/起风了_63.TextGrid
# /content/SingingVoice-Auto-Alignment-Revised/my_textgrid/起风了_51.TextGrid
# /content/SingingVoice-Auto-Alignment-Revised/my_textgrid/起风了_21.TextGrid
# /content/SingingVoice-Auto-Alignment-Revised/my_textgrid/起风了_44.TextGrid
# /content/SingingVoice-Auto-Alignment-Revised/my_textgrid/起风了_20.TextGrid
# /content/SingingVoice-Auto-Alignment-Revised/my_textgrid/年轮_1.TextGrid
# /content/SingingVoice-Auto-Alignment-Revised/my_textgrid/年轮_19.TextGrid
# /content/SingingVoice-Auto-Alignment-Revised/my_textgrid/年轮_33.TextGrid
# /content/SingingVoice-Auto-Alignment-Revised/my_textgrid/起风了_55.TextGrid
# /content/SingingVoice-Auto-Alignment-Revised/my_textgrid/年轮_10.TextGrid
# /content/SingingVoice-Auto-Alignment-Revised/my_textgrid/年轮_13.TextGrid
# ...
